# %%
library(tidyverse)
library(nycflights13)
library(lubridate)
# to use original type
# stats::filter()
#  stats::lag()

# nycflights13::flights
# ?nycflights13::flights

# filter()
# arrange()
# select()
# mutate()
# summarize()
# group_by()
# Out:
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.3.0     v purrr   0.3.3
# v tibble  3.0.0     v dplyr   0.8.5
# v tidyr   1.0.2     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"Warning message:
# "package 'tibble' was built under R version 3.6.3"Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'purrr' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"Warning message:
# "package 'stringr' was built under R version 3.6.2"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# Warning message:
# "package 'nycflights13' was built under R version 3.6.3"Warning message:
# "package 'lubridate' was built under R version 3.6.3"
# Attaching package: 'lubridate'
#
# The following objects are masked from 'package:dplyr':
#
#     intersect, setdiff, union
#
# The following objects are masked from 'package:base':
#
#     date, intersect, setdiff, union

# %%
diamonds %>%
count(cut)

ggplot(data = diamonds) +
geom_bar(mapping = aes(x = cut))
# Out:
#   cut       n
# 1 Fair       1610
# 2 Good       4906
# 3 Very Good 12082
# 4 Premium   13791
# 5 Ideal     21551
# plot without title

# %%
diamonds %>%
count(cut_width(carat, 0.5))


ggplot(data = diamonds) +
geom_histogram(mapping = aes(x = carat), binwidth = 0.5
              )
# Out:
#    cut_width(carat, 0.5) n
# 1  [-0.25,0.25]            785
# 2  (0.25,0.75]           29498
# 3  (0.75,1.25]           15977
# 4  (1.25,1.75]            5313
# 5  (1.75,2.25]            2002
# 6  (2.25,2.75]             322
# 7  (2.75,3.25]              32
# 8  (3.25,3.75]               5
# 9  (3.75,4.25]               4
# 10 (4.25,4.75]               1
# 11 (4.75,5.25]               1
# plot without title

# %%
smaller <- diamonds %>%
filter(carat < 3)
ggplot(data = smaller, mapping = aes(x = carat)) +
geom_histogram(binwidth = 0.1)
# Out:
# plot without title

# %%
ggplot(data = smaller, mapping = aes(x = carat, color = cut)) +
geom_freqpoly(binwidth = 0.1)
# Out:
# plot without title

# %%
ggplot(data = smaller, mapping = aes(x = carat)) +
geom_histogram(binwidth = 0.01)
# Out:
# plot without title

# %%
ggplot(data = faithful, mapping = aes(x = eruptions)) +
geom_histogram(binwidth = 0.25)
# Out:
# plot without title

# %%
ggplot(diamonds) +
geom_histogram(mapping = aes(x = y), binwidth = 0.5) +
coord_cartesian(ylim = c(0, 50))

diamonds %>% filter(y < 3 | y > 20) %>% arrange(y)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 1.00  Very Good H     VS2     63.3  53     5139 0.00  0.0 0.00
# 2 1.14  Fair      G     VS1     57.5  67     6381 0.00  0.0 0.00
# 3 1.56  Ideal     G     VS2     62.2  54    12800 0.00  0.0 0.00
# 4 1.20  Premium   D     VVS1    62.1  59    15686 0.00  0.0 0.00
# 5 2.25  Premium   H     SI2     62.8  59    18034 0.00  0.0 0.00
# 6 0.71  Good      F     SI2     64.1  60     2130 0.00  0.0 0.00
# 7 0.71  Good      F     SI2     64.1  60     2130 0.00  0.0 0.00
# 8 0.51  Ideal     E     VS1     61.8  55     2075 5.15 31.8 5.12
# 9 2.00  Premium   H     SI2     58.9  57    12210 8.09 58.9 8.06
# plot without title

# %%
# Exercise Page 90
# 1

ggplot(diamonds) +
geom_histogram(mapping = aes(x = x), binwidth = 0.5)

ggplot(diamonds) +
geom_histogram(mapping = aes(x = y), binwidth = 0.5)

ggplot(diamonds) +
geom_histogram(mapping = aes(x = z), binwidth = 0.5)
# Out:
# plot without title
# plot without title
# plot without title

# %%
# Exercise Page 90
# 1
# x and y has same distribution but y has some extra outliers
# to see outliers

ggplot(diamonds) +
geom_histogram(mapping = aes(x = y), binwidth = 0.5) +
coord_cartesian(ylim = c(0, 50))
# Out:
# plot without title

# %%
# Exercise Page 90
# 1

cor(diamonds$x, diamonds$y)
mean(with(diamonds, round(x, 0) == round(y, 0)))

diamonds %>%
  gather(key = dist, vals, x, y, z) %>%
  ggplot(aes(vals, colour = dist)) +
  geom_freqpoly(bins = 80)
# Out:
# [1] 0.9747015
# [1] 0.9524842
# plot without title

# %%
#?gather
# Exercise Page 90
# 1
diamonds %>%
  filter(y < 30) %>%
  select(x, y, z) #%>%
  #ggpairs() # kaj korche na
# Out:
#       x    y    z
# 1     3.95 3.98 2.43
# 2     3.89 3.84 2.31
# 3     4.05 4.07 2.31
# 4     4.20 4.23 2.63
# 5     4.34 4.35 2.75
# 6     3.94 3.96 2.48
# 7     3.95 3.98 2.47
# 8     4.07 4.11 2.53
# 9     3.87 3.78 2.49
# 10    4.00 4.05 2.39
# 11    4.25 4.28 2.73
# 12    3.93 3.90 2.46
# 13    3.88 3.84 2.33
# 14    4.35 4.37 2.71
# 15    3.79 3.75 2.27
# 16    4.38 4.42 2.68
# 17    4.31 4.34 2.68
# 18    4.23 4.29 2.70
# 19    4.23 4.26 2.71
# 20    4.21 4.27 2.66
# 21    4.26 4.30 2.71
# 22    3.85 3.92 2.48
# 23    3.94 3.96 2.41
# 24    4.39 4.43 2.62
# 25    4.44 4.47 2.59
# 26    3.97 4.01 2.41
# 27    3.97 3.94 2.47
# 28    4.28 4.30 2.67
# 29    3.96 3.97 2.40
# 30    3.96 3.99 2.42
# ...   ...  ...  ...
# 53909 5.74 5.77 3.48
# 53910 5.43 5.38 3.23
# 53911 5.48 5.40 3.36
# 53912 5.84 5.81 3.74
# 53913 5.94 5.90 3.77
# 53914 5.84 5.86 3.63
# 53915 5.71 5.74 3.61
# 53916 6.12 6.09 3.86
# 53917 5.93 5.85 3.49
# 53918 5.89 5.87 3.66
# 53919 5.57 5.61 3.49
# 53920 5.59 5.65 3.53
# 53921 5.67 5.58 3.55
# 53922 5.80 5.84 3.57
# 53923 5.82 5.84 3.59
# 53924 5.95 5.97 3.67
# 53925 5.71 5.73 3.54
# 53926 6.06 6.13 3.54
# 53927 6.03 5.96 3.68
# 53928 5.76 5.73 3.53
# 53929 5.79 5.74 3.49
# 53930 5.74 5.73 3.43
# 53931 5.71 5.76 3.47
# 53932 5.69 5.72 3.49
# 53933 5.69 5.73 3.58
# 53934 5.75 5.76 3.50
# 53935 5.69 5.75 3.61
# 53936 5.66 5.68 3.56
# 53937 6.15 6.12 3.74
# 53938 5.83 5.87 3.64

# %%
# Exercise Page 90
# 2

ggplot(diamonds) +
geom_histogram(mapping = aes(x = price), binwidth = 1000) #+
# coord_cartesian(ylim = c(0, 50))
# Out:
# plot without title

# %%
# Exercise Page 90
# 2
graph <- map(seq(50, 1000, 100),
             ~ ggplot(diamonds, aes(x = price)) +
               geom_histogram(bins = .x) +
               labs(x = NULL, y = NULL) +
               scale_x_continuous(labels = NULL) +
               scale_y_continuous(labels = NULL))

multiplot(plotlist = graph)
# Out:
# Error in multiplot(plotlist = graph): could not find function "multiplot"
# Traceback:

# %%
# Exercise Page 90
# 3
diamonds %>%
  filter(carat %in% c(0.99, 1)) %>%
  count(carat)
# Out:
#   carat n
# 1 0.99    23
# 2 1.00  1558

# %%
# Exercise Page 90
# 4

ggplot(diamonds) +
geom_histogram(mapping = aes(x = y), binwidth = 0.5) +
coord_cartesian(ylim = c(0, 50))

ggplot(diamonds) +
geom_histogram(mapping = aes(x = y), binwidth = 0.5) +
ylim(0, 50)
# Out:
# Warning message:
# "Removed 11 rows containing missing values (geom_bar)."
# plot without title
# plot without title

# %%
# Exercise Page 90
# 4

diamonds %>%
  ggplot(aes(y)) +
  geom_histogram() +
  coord_cartesian(ylim = c(0, 50))
# Note how xlim deleted the observations at 0.

diamonds %>%
  ggplot(aes(y)) +
  geom_histogram() +
  xlim(c(0, 60)) +
  coord_cartesian(y = c(0, 50))

# Also note how xlim and ylim inside coord_cartesian don't exclude the data
diamonds %>%
  ggplot(aes(y)) +
  geom_histogram(bins = 30) +
  coord_cartesian(xlim = c(2, 60), ylim = c(0, 50))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# "Removed 2 rows containing missing values (geom_bar)."
# plot without title
# plot without title
# plot without title
